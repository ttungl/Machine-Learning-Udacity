# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

# array = [[13,1,1,0,2,0],
#      [3,9,6,0,1,0],
#      [0,0,16,2,0,0],
#      [0,0,0,13,0,0],
#      [0,0,0,0,15,0],
#      [0,0,1,0,0,15]] 

array = [[0.88,0.12],
         [0.03,0.97]]
   
df_cm = pd.DataFrame(array, range(2),range(2))
plt.figure(figsize = (10,7))
sn.set(font_scale=5)#for label size

sn.heatmap(df_cm, annot=True,annot_kws={"size": 45})# font size
plt.ylabel('True configuration label', fontsize=35)
plt.xlabel('Predicted configuration label', fontsize=35)
plt.show()
